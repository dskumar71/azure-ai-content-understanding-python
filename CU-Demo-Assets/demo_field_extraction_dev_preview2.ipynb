# %% [markdown]
# # Extract Custom Fields from Your File

# %% [markdown]
# This notebook demonstrates how to use analyzers to extract custom fields from your input files.

# %% [markdown]
# ## Prerequisites
# 1. Ensure Azure AI service is configured following [steps](../README.md#configure-azure-ai-service-resource)
# 2. Install the required packages to run the sample.

# %%
# %pip install -r ../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: azure-identity in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (1.19.0)
# Requirement already satisfied: python-dotenv in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: Pillow in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (11.1.0)
# Requirement already satisfied: azure-core>=1.31.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.32.0)
# Requirement already satisfied: cryptography>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (44.0.0)
# Requirement already satisfied: msal>=1.30.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (2024.12.14)
# Requirement already satisfied: six>=1.11.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-core>=1.31.0->azure-identity->-r ../requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in /home/vscode/.local/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity->-r ../requirements.txt (line 1)) (1.17.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->-r ../requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: portalocker<3,>=1.4 in /home/vscode/.local/lib/python3.11/site-packages (from msal-extensions>=1.2.0->azure-identity->-r ../requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity->-r ../requirements.txt (line 1)) (2.22)
#
# [notice] A new release of pip is available: 24.0 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Analyzer Templates

# %% [markdown]
# Below is a collection of analyzer templates designed to extract fields from various input file types.
#
# These templates are highly customizable, allowing you to modify them to suit your specific needs. For additional verified templates from Microsoft, please visit [here](../analyzer_templates/README.md).

# %%
extraction_templates = {
    "invoice":            ('../analyzer_templates/invoice.json',         '../data/invoice.pdf'            ),
    "chart":              ('../analyzer_templates/image_chart.json',     '../data/pieChart.jpg'           ),
    "call_recording":     ('../analyzer_templates/call_recording_analytics.json', '../data/callCenterRecording.mp3'),
    "conversation_audio": ('../analyzer_templates/conversational_audio_analytics.json', '../data/callCenterRecording.mp3'),
    "marketing_video":    ('../analyzer_templates/marketing_video.json', '../data/video.mp4'              ),
    "PostCallAnalyticsOnText":  ('../CU-Demo-Assets/analyzers/PostCallAnalyticsOnText.json', '../CU-Demo-Assets/en-us-conversation-transcripts/sample0 - Insurance - Customer calls about purchasing life insurance.wav.results.txt'),
    "PostCallAnalyticsCustomized": ('../CU-Demo-Assets/analyzers/PostCallAnalyticsCustomized.json', '../CU-Demo-Assets/en-US-mono-audio/sample4 - Healthcare - Customer calls about new policy quote.wav'),
    "PostCallAnalyticsCustomizedDE": ('../CU-Demo-Assets/analyzers/PostCallAnalyticsWithGermanResult.json', '../CU-Demo-Assets/de-DE-mono-audio/sample4 - Healthcare - Customer calls about new policy quote- German.wav'),
    "ImageTextAnalysis": ('../CU-Demo-Assets/analyzers/imageTextAnalysis.json', '../CU-Demo-Assets/en-us-images-w-text/Designer.png'),
    "MultiLanguageDemo": ('../CU-Demo-Assets/analyzers/MultiLanguageDemo.json', '../CU-Demo-Assets/pt-BR-mono-audio/sample4 - Healthcare - Customer calls about new policy quote - Brazilian.wav'),
    "MultiLanguageDemoOnText":  ('../CU-Demo-Assets/analyzers/MultiLanguageDemoOnText.json', '../CU-Demo-Assets/pt-BR-conversation-transcripts/sample6 - Financial - Customer calls about transferring funds - Brazilian.wav.results.txt'),
    "PostCallAnalyticsCustomizedMultiLanguageMoreFields":  ('../CU-Demo-Assets/analyzers/PostCallAnalyticsCustomizedMultiLanguageMoreFields.json', '../CU-Demo-Assets/de-DE-mono-audio/sample4 - Healthcare - Customer calls about new policy quote- German.wav'),
    "ACSTesting":  ('../CU-Demo-Assets/analyzers/ACSTesting.json', '../CU-Demo-Assets/en-US-mono-audio/sample4 - Healthcare - Customer calls about new policy quote.wav'),
    "ACSTestingIRCLog": ('../CU-Demo-Assets/analyzers/ACSTestingIRCLog.json', '../CU-Demo-Assets/en-us-text-examples/linux.log.txt'),
    "CarInsuranceCallAnalysis":  ('../CU-Demo-Assets/analyzers/CarInsuranceCallAnalysis.json', '../CU-Demo-Assets/en-US-mono-audio/Car Insurance Call.wav'),
    "StoryAnalysis": ('../CU-Demo-Assets/analyzers/HTML-ShortStoryAnalyzer.json', '../CU-Demo-Assets/en-us-text-examples/extended_short_story.html'),
    "StoryAnalysisWObject": ('../CU-Demo-Assets/analyzers/HTML-ShortStoryAnalyzerWObject.json', '../CU-Demo-Assets/en-us-text-examples/extended_short_story.html')
}

# %% [markdown]
# Specify the analyzer template you want to use and provide a name for the analyzer to be created based on the template.

# %%
import uuid

ANALYZER_TEMPLATE = "PostCallAnalyticsCustomized"
ANALYZER_ID = "cu-demo-" + str(uuid.uuid4())

(analyzer_template_path, analyzer_sample_file_path) = extraction_templates[ANALYZER_TEMPLATE]
print(f"Analyzer template path: {analyzer_template_path}")
print(f"Analyzer sample file path: {analyzer_sample_file_path}")
# Out:
# Analyzer template path: ../CU-Demo-Assets/analyzers/PostCallAnalyticsCustomized.json
# Analyzer sample file path: ../CU-Demo-Assets/en-US-mono-audio/sample4 - Healthcare - Customer calls about new policy quote.wav

# %% [markdown]
# ## Create Azure AI Content Understanding Client
#
# > The [AzureContentUnderstandingClient](../python/content_understanding_client.py) is a utility class containing functions to interact with the Content Understanding API. Before the official release of the Content Understanding SDK, it can be regarded as a lightweight SDK.

# %%
import logging
import json
import os
import sys
from pathlib import Path
from dotenv import find_dotenv, load_dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

load_dotenv(find_dotenv())
logging.basicConfig(level=logging.INFO)

AZURE_AI_ENDPOINT = os.getenv("dev_preview2_endpoint")
AZURE_AI_API_VERSION = os.getenv("dev_preview2_api_version")
AZURE_AI_SUBSCRIPTION_KEY = os.getenv("dev_preview2_subscription_key", None)

# Add the parent directory to the path to use shared modules
parent_dir = Path(Path.cwd()).parent
sys.path.append(str(parent_dir))
from python.content_understanding_client_dev_preview2 import AzureContentUnderstandingClient

credential = DefaultAzureCredential()
token_provider = get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")

client = AzureContentUnderstandingClient(
    endpoint=AZURE_AI_ENDPOINT,
    api_version=AZURE_AI_API_VERSION,
    subscription_key=AZURE_AI_SUBSCRIPTION_KEY,
    token_provider=token_provider,
    x_ms_useragent="azure-ai-content-understanding-python/field_extraction", # This header is used for sample usage telemetry, please comment out this line if you want to opt out.
)
# Out:
# INFO:azure.identity._credentials.environment:No environment configuration found.
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.19.0 Python/3.11.11 (Linux-6.8.0-1026-azure-x86_64-with-glibc2.36)'
# No body was attached to the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 400
# Response headers:
#     'Content-Type': 'application/json; charset=utf-8'
#     'Server': 'IMDS/150.870.65.1544'
#     'x-ms-request-id': '2b077227-0fc9-4df4-b8de-0a7484936562'
#     'Date': 'Fri, 02 May 2025 23:59:48 GMT'
#     'Content-Length': '88'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Metadata': 'REDACTED'
#     'User-Agent': 'azsdk-python-identity/1.19.0 Python/3.11.11 (Linux-6.8.0-1026-azure-x86_64-with-glibc2.36)'
# No body was attached to the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 400
# Response headers:
#     'Content-Type': 'application/json; charset=utf-8'
#     'Server': 'IMDS/150.870.65.1544'
#     'x-ms-request-id': '77ab95fb-8970-41a5-86e9-8980efeca0ed'
#     'Date': 'Fri, 02 May 2025 23:59:48 GMT'
#     'Content-Length': '68'
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureDeveloperCliCredential

# %% [markdown]
# ## List all analyzers created in your resource

# %% [markdown]
# After the analyzer is successfully created, we can use it to analyze our input files.

# %%
response = client.get_all_analyzers()
print(f"Number of analyzers in your resource: {len(response['value'])}")
print(f"First 3 analyzer details: {json.dumps(response['value'], indent=2)}")
# Out:
# Number of analyzers in your resource: 7
# First 3 analyzer details: [
#   {
#     "analyzerId": "prebuilt-callCenter",
#     "description": "Analyze call center conversations to extract transcripts, summaries, sentiment, and more.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": false,
#       "disableContentFiltering": false,
#       "segmentationMode": "noSegmentation",
#       "tableFormat": "html"
#     },
#     "fieldSchema": {
#       "name": "PostCallAnalytics",
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "description": "A one-paragraph summary"
#         },
#         "Topics": {
#           "type": "array",
#           "description": "Top 5 topics mentioned",
#           "items": {
#             "type": "string"
#           }
#         },
#         "Companies": {
#           "type": "array",
#           "description": "List of companies mentioned",
#           "items": {
#             "type": "string"
#           }
#         },
#         "People": {
#           "type": "array",
#           "description": "List of people mentioned",
#           "items": {
#             "type": "object",
#             "properties": {
#               "Name": {
#                 "type": "string",
#                 "description": "Person's name"
#               },
#               "Role": {
#                 "type": "string",
#                 "description": "Person's title/role"
#               }
#             }
#           }
#         },
#         "Sentiment": {
#           "type": "string",
#           "method": "classify",
#           "description": "Overall sentiment",
#           "enum": [
#             "Positive",
#             "Neutral",
#             "Negative"
#           ]
#         },
#         "Categories": {
#           "type": "array",
#           "method": "classify",
#           "description": "List of relevant categories",
#           "items": {
#             "type": "string",
#             "enum": [
#               "Agriculture",
#               "Business",
#               "Finance",
#               "Health",
#               "Insurance",
#               "Mining",
#               "Pharmaceutical",
#               "Retail",
#               "Technology",
#               "Transportation"
#             ]
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-conversation",
#     "description": "Transcribe conversations and extract summaries.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": false,
#       "disableContentFiltering": false,
#       "segmentationMode": "noSegmentation",
#       "tableFormat": "html"
#     },
#     "fieldSchema": {
#       "name": "ConversationSummarization",
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "description": "A one-paragraph summary of the conversation."
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-ocr",
#     "description": "Extract various content and layout elements such as words, paragraphs, and tables from documents.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": false,
#       "enableOcr": true,
#       "enableBarcode": false,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "segmentationMode": "noSegmentation",
#       "tableFormat": "html"
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-image",
#     "description": "Analyze images to extract structured fields.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": false,
#       "disableContentFiltering": false,
#       "segmentationMode": "noSegmentation",
#       "tableFormat": "html"
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-text",
#     "description": "Analyze texts to extract structured fields.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": false,
#       "disableContentFiltering": false,
#       "segmentationMode": "noSegmentation",
#       "tableFormat": "html"
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-invoice",
#     "description": "Extract invoice document fields.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": false,
#       "enableOcr": true,
#       "enableBarcode": false,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "segmentationMode": "noSegmentation",
#       "tableFormat": "html"
#     },
#     "fieldSchema": {
#       "fields": {
#         "CustomerName": {
#           "type": "string",
#           "method": "extract",
#           "description": "The full name of the customer, including the primary company name and associated identifiers such as C/O (Care Of), BU# (Business Unit number), ATTN: (Attention to), department names, or other relevant details if existing."
#         },
#         "InvoiceDate": {
#           "type": "date",
#           "method": "extract"
#         },
#         "CustomerId": {
#           "type": "string",
#           "method": "extract"
#         },
#         "PurchaseOrder": {
#           "type": "string",
#           "method": "extract"
#         },
#         "InvoiceId": {
#           "type": "string",
#           "method": "extract",
#           "description": "The unique identifier of the invoice, often named 'Invoice Number'"
#         },
#         "DueDate": {
#           "type": "date",
#           "method": "extract"
#         },
#         "VendorName": {
#           "type": "string",
#           "method": "extract"
#         },
#         "VendorAddress": {
#           "type": "string",
#           "method": "extract"
#         },
#         "VendorAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "CustomerAddress": {
#           "type": "string",
#           "method": "extract"
#         },
#         "CustomerAddressRecipient": {
#           "type": "string",
#           "method": "extract",
#           "description": "The recepient of customer addresss, including the recepient and associated identifiers such as C/O (Care Of), BU# (Business Unit number), ATTN: (Attention to), department names, or other relevant details if existing. Ensure that all parts related to the customer\u2019s recepient identification are included to provide complete context."
#         },
#         "BillingAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "The explicit billing address of the customer."
#         },
#         "BillingAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "ShippingAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "The explicit shipping address of the customer."
#         },
#         "ShippingAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "SubTotal": {
#           "type": "number",
#           "method": "extract"
#         },
#         "TotalDiscount": {
#           "type": "number",
#           "method": "extract"
#         },
#         "TotalTax": {
#           "type": "number",
#           "method": "extract"
#         },
#         "InvoiceTotal": {
#           "type": "number",
#           "method": "extract"
#         },
#         "AmountDue": {
#           "type": "number",
#           "method": "extract"
#         },
#         "PreviousUnpaidBalance": {
#           "type": "number",
#           "method": "extract",
#           "description": "Explicit previously unpaid balance. Please make sure it is **unpaid**, not the total amount of the previous invoice."
#         },
#         "RemittanceAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "The explicit address to which the payment or remittance should be sent."
#         },
#         "RemittanceAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "ServiceAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "The explicit address where the service was provided."
#         },
#         "ServiceAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "VendorTaxId": {
#           "type": "string",
#           "method": "extract",
#           "description": "The government ID number associated with the vendor"
#         },
#         "CustomerTaxId": {
#           "type": "string",
#           "method": "extract",
#           "description": "The government ID number associated with the customer"
#         },
#         "PaymentTerm": {
#           "type": "string",
#           "method": "extract"
#         },
#         "TaxDetails": {
#           "type": "array",
#           "method": "extract",
#           "description": "The tax details of the invoice.",
#           "items": {
#             "type": "object",
#             "method": "extract",
#             "properties": {
#               "Amount": {
#                 "type": "number",
#                 "method": "extract"
#               },
#               "Rate": {
#                 "type": "number",
#                 "method": "extract"
#               }
#             }
#           }
#         },
#         "Items": {
#           "type": "array",
#           "method": "extract",
#           "items": {
#             "type": "object",
#             "method": "extract",
#             "properties": {
#               "TotalPrice": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The total amount of the line item."
#               },
#               "Date": {
#                 "type": "date",
#                 "method": "extract"
#               },
#               "Description": {
#                 "type": "string",
#                 "method": "extract"
#               },
#               "Quantity": {
#                 "type": "number",
#                 "method": "extract"
#               },
#               "ProductCode": {
#                 "type": "string",
#                 "method": "extract",
#                 "description": "Product code, product number, or SKU associated with the specific line item"
#               },
#               "TaxAmount": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The tax amount of the line item."
#               },
#               "TaxRate": {
#                 "type": "number",
#                 "method": "extract"
#               },
#               "Unit": {
#                 "type": "string",
#                 "method": "extract"
#               },
#               "UnitPrice": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The net or gross price of one unit of the item"
#               }
#             }
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-video",
#     "description": "Analyze videos to extract transcript and structured fields for each shot.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "locales": [
#         "en-US",
#         "es-ES",
#         "es-MX",
#         "fr-FR",
#         "hi-IN",
#         "it-IT",
#         "ja-JP",
#         "ko-KR",
#         "pt-BR",
#         "zh-CN"
#       ],
#       "returnDetails": false,
#       "enableFace": false,
#       "disableContentFiltering": false,
#       "segmentationMode": "noSegmentation",
#       "tableFormat": "html"
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   }
# ]

# %% [markdown]
# ## Create Analyzer from the Template

# %%
response = client.begin_create_analyzer(ANALYZER_ID, analyzer_template_path=analyzer_template_path)
result = client.poll_result(response)

print(json.dumps(result, indent=2))
# Out:
# INFO:python.content_understanding_client_dev_preview2:Analyzer cu-demo-13b055c7-d293-4bb3-911e-3ea3d8bb38e6 create request accepted.
# INFO:python.content_understanding_client_dev_preview2:Request result is ready after 0.00 seconds.
# {
#   "id": "f16a208e-a1b9-4421-8aba-eb7e60e5610d",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "cu-demo-13b055c7-d293-4bb3-911e-3ea3d8bb38e6",
#     "description": "Customized Post Call Analytics Analyzer incl. Issue- and Resolution Summaries and extended sentiment descriptions",
#     "tags": {
#       "projectId": "",
#       "templateId": "postCallAnalytics-2024-12-01"
#     },
#     "createdAt": "2025-05-02T23:59:51Z",
#     "lastModifiedAt": "2025-05-02T23:59:51Z",
#     "baseAnalyzerId": "prebuilt-callCenter",
#     "config": {
#       "locales": [
#         "en-US",
#         "de-DE",
#         "pt-BR"
#       ],
#       "returnDetails": true,
#       "disableContentFiltering": false,
#       "segmentationMode": "noSegmentation",
#       "tableFormat": "html",
#       "estimateFieldSourceAndConfidence": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "method": "generate",
#           "description": "A one-paragraph summary"
#         },
#         "Topics": {
#           "type": "array",
#           "method": "generate",
#           "description": "Top 5 topics mentioned",
#           "items": {
#             "type": "string",
#             "method": "generate"
#           }
#         },
#         "Companies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List of companies mentioned",
#           "items": {
#             "type": "string",
#             "method": "generate"
#           }
#         },
#         "People": {
#           "type": "array",
#           "method": "generate",
#           "description": "List of people mentioned",
#           "items": {
#             "type": "object",
#             "method": "generate",
#             "properties": {
#               "Name": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Person's name"
#               },
#               "Role": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Person's title/role"
#               }
#             }
#           }
#         },
#         "Sentiment": {
#           "type": "string",
#           "method": "classify",
#           "description": "Overall sentiment",
#           "enum": [
#             "Positive",
#             "Neutral",
#             "Negative"
#           ],
#           "enumDescriptions": {
#             "Positive": "The customer expresses satisfaction and a positive experience.",
#             "Neutral": "The customer shows neither strong positive nor negative feelings; their experience is mixed.",
#             "Negative": "The customer expresses dissatisfaction, frustration, or other negative emotions."
#           }
#         },
#         "Categories": {
#           "type": "array",
#           "method": "generate",
#           "description": "List of relevant categories",
#           "items": {
#             "type": "string",
#             "method": "classify",
#             "enum": [
#               "Agriculture",
#               "Business",
#               "Finance",
#               "Health",
#               "Insurance",
#               "Mining",
#               "Pharmaceutical",
#               "Retail",
#               "Technology",
#               "Transportation"
#             ]
#           }
#         },
#         "IssueSummary": {
#           "type": "string",
#           "method": "generate",
#           "description": "A short list of the caller\"s issue(s)"
#         },
#         "ResolutionSummary": {
#           "type": "string",
#           "method": "generate",
#           "description": "A short list of actions how the issue was resolved"
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   }
# }

# %% [markdown]
# # Extract Conversation (WEBVTT) from either Batch Transcription JSON or Content Understanding JSON

# %% [markdown]
# ## Extract Fields Using the Analyzer

# %% [markdown]
# After the analyzer is successfully created, we can use it to analyze our input files.

# %%
# ANALYZER_ID = "prebuilt-callCenter"
response = client.begin_analyze(ANALYZER_ID, file_location=analyzer_sample_file_path)
result = client.poll_result(response)

print(json.dumps(result, indent=2))
# Out:
# INFO:python.content_understanding_client_dev_preview2:Analyzing file ../CU-Demo-Assets/en-US-mono-audio/sample4 - Healthcare - Customer calls about new policy quote.wav with analyzer: cu-demo-13b055c7-d293-4bb3-911e-3ea3d8bb38e6
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request eb426a6e-86f5-4c66-9e8d-4852620ea88f in progress ...
# INFO:python.content_understanding_client_dev_preview2:Request result is ready after 32.29 seconds.
# {
#   "id": "eb426a6e-86f5-4c66-9e8d-4852620ea88f",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "cu-demo-13b055c7-d293-4bb3-911e-3ea3d8bb38e6",
#     "apiVersion": "2025-05-01-preview",
#     "createdAt": "2025-05-02T23:59:52Z",
#     "stringEncoding": "utf8",
#     "warnings": [],
#     "contents": [
#       {
#         "markdown": "# Audio: 00:00.000 => 03:02.112\n\nTranscript\n```\nWEBVTT\n\n00:00.080 --> 00:03.680\n<v Speaker 1>Hi, thank you for calling Contoso, who am I speaking with today?\n\n00:04.560 --> 00:06.240\n<v Speaker 1>Hi, my name is Mary Rondo.\n\n00:07.120 --> 00:09.360\n<v Speaker 1>I was trying to enroll myself with Contoso.\n\n00:10.160 --> 00:13.200\n<v Speaker 1>Hi Mary, are you calling because you need health insurance?\n\n00:14.080 --> 00:16.400\n<v Speaker 1>Yes, I am calling to sign up for insurance.\n\n00:17.280 --> 00:21.280\n<v Speaker 1>Great, if you can answer a few questions, we can get you signed up in a jiffy.\n\n00:22.160 --> 00:22.640\n<v Speaker 1>Okay.\n\n00:23.520 --> 00:25.040\n<v Speaker 1>So, what is your full name?\n\n00:25.920 --> 00:27.040\n<v Speaker 1>Mary Beth Rondo.\n\n00:27.840 --> 00:33.680\n<v Speaker 1>Last name is R, like Romeo O, like Ocean N, like Nancy D, like dog and O like ocean.\n\n00:34.480 --> 00:37.120\n<v Speaker 1>Romeo Oscar November Delta Oscar, got it.\n\n00:38.000 --> 00:41.280\n<v Speaker 1>And what's the best call back number in case we get disconnected?\n\n00:42.240 --> 00:44.400\n<v Speaker 1>I only have a cell phone so I can give you that.\n\n00:45.280 --> 00:46.480\n<v Speaker 1>Yes, that would be fine.\n\n00:47.360 --> 00:49.360\n<v Speaker 1>Sure, it's two hundred and thirty four.\n\n00:50.240 --> 00:51.600\n<v Speaker 1>Two hundred and thirty four.\n\n00:52.560 --> 00:54.080\n<v Speaker 1>Five hundred and fifty four.\n\n00:55.120 --> 00:55.280\n<v Speaker 1>Mom.\n\n00:56.240 --> 00:58.400\n<v Speaker 1>And then 9312.\n\n00:59.280 --> 00:59.760\n<v Speaker 1>Got it.\n\n00:59.920 --> 01:03.760\n<v Speaker 1>So to confirm it's 2345549312.\n\n01:04.560 --> 01:05.760\n<v Speaker 1>Yes, that's right.\n\n01:06.640 --> 01:07.280\n<v Speaker 1>Excellent.\n\n01:08.160 --> 01:10.960\n<v Speaker 1>Let's get some additional information for your application.\n\n01:11.840 --> 01:12.720\n<v Speaker 1>Do you have a job?\n\n01:13.600 --> 01:15.200\n<v Speaker 1>Yes, I am self-employed.\n\n01:16.080 --> 01:18.560\n<v Speaker 1>Okay, then do you have a social security number?\n\n01:19.440 --> 01:20.240\n<v Speaker 1>Yes, I do.\n\n01:21.080 --> 01:22.960\n<v Speaker 1>What is your social security number?\n\n01:23.840 --> 01:25.360\n<v Speaker 1>It is 412.\n\n01:26.240 --> 01:32.240\n<v Speaker 1>256789 Sorry, was that a twenty-five or a two hundred and twenty-five?\n\n01:32.400 --> 01:33.520\n<v Speaker 1>You cut out for a bit.\n\n01:34.400 --> 01:37.600\n<v Speaker 1>It's a double two so four one two then another two then five.\n\n01:38.560 --> 01:39.600\n<v Speaker 1>Thank you so much.\n\n01:40.400 --> 01:42.240\n<v Speaker 1>Could I please have you e-mail address?\n\n01:43.120 --> 01:43.600\n<v Speaker 1>Yeah.\n\n01:44.400 --> 01:45.040\n<v Speaker 1>It's Mary.\n\n01:45.840 --> 01:46.480\n<v Speaker 1>Rondo.\n\n01:47.280 --> 01:48.560\n<v Speaker 1>At gmail.com.\n\n01:49.440 --> 01:52.080\n<v Speaker 1>So my first and last name at gmail.com.\n\n01:52.880 --> 01:53.840\n<v Speaker 1>No periods.\n\n01:54.720 --> 01:55.680\n<v Speaker 1>No dashes.\n\n01:56.480 --> 02:02.160\n<v Speaker 1>Great, that is the last question, so let me take your information, and I will be able to get you signed up right away.\n\n02:03.040 --> 02:07.600\n<v Speaker 1>Thank you very much for calling Contoso, and I will be able to get you signed up immediately.\n\n02:08.480 --> 02:12.880\n<v Speaker 1>One of our agents will call you back within 24 hours to confirm your application.\n\n02:13.760 --> 02:14.640\n<v Speaker 1>That was quick.\n\n02:15.440 --> 02:16.080\n<v Speaker 1>Thank you.\n\n02:16.880 --> 02:24.160\n<v Speaker 1>If you need anything else please give us a call at 1-800-555-555, extension 123.\n\n02:24.480 --> 02:26.560\n<v Speaker 1>Thank you very much for calling Contoso.\n\n02:27.440 --> 02:29.200\n<v Speaker 1>Actually I have one more question.\n\n02:30.000 --> 02:31.040\n<v Speaker  ...
#         "fields": {
#           "Summary": {
#             "type": "string",
#             "valueString": "Mary Rondo called Contoso to enroll in health insurance. She provided her personal details, including her full name, phone number, email address, and social security number. She also requested a physical membership card to be mailed to her address. The representative confirmed that her application would be processed, and an agent would call her back within 24 hours to confirm the application."
#           },
#           "Topics": {
#             "type": "array",
#             "valueArray": [
#               {
#                 "type": "string",
#                 "valueString": "Health insurance enrollment"
#               },
#               {
#                 "type": "string",
#                 "valueString": "Personal information"
#               },
#               {
#                 "type": "string",
#                 "valueString": "Membership card"
#               },
#               {
#                 "type": "string",
#                 "valueString": "Application process"
#               },
#               {
#                 "type": "string",
#                 "valueString": "Customer support"
#               }
#             ]
#           },
#           "Companies": {
#             "type": "array",
#             "valueArray": [
#               {
#                 "type": "string",
#                 "valueString": "Contoso"
#               }
#             ]
#           },
#           "People": {
#             "type": "array",
#             "valueArray": [
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "Name": {
#                     "type": "string",
#                     "valueString": "Mary Rondo"
#                   },
#                   "Role": {
#                     "type": "string",
#                     "valueString": "Customer"
#                   }
#                 }
#               }
#             ]
#           },
#           "Sentiment": {
#             "type": "string",
#             "valueString": "Positive"
#           },
#           "Categories": {
#             "type": "array",
#             "valueArray": [
#               {
#                 "type": "string",
#                 "valueString": "Health"
#               },
#               {
#                 "type": "string",
#                 "valueString": "Insurance"
#               }
#             ]
#           },
#           "IssueSummary": {
#             "type": "string",
#             "valueString": "Mary Rondo wanted to enroll in health insurance and requested a physical membership card."
#           },
#           "ResolutionSummary": {
#             "type": "string",
#             "valueString": "The representative collected her details, confirmed the application process, and noted her request for a physical card to be mailed."
#           }
#         },
#         "kind": "audioVisual",
#         "startTimeMs": 0,
#         "endTimeMs": 182112,
#         "transcriptPhrases": [
#           {
#             "speaker": "1",
#             "startTimeMs": 80,
#             "endTimeMs": 3680,
#             "text": "Hi, thank you for calling Contoso, who am I speaking with today?",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 4560,
#             "endTimeMs": 6240,
#             "text": "Hi, my name is Mary Rondo.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 7120,
#             "endTimeMs": 9360,
#             "text": "I was trying to enroll myself with Contoso.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 10160,
#             "endTimeMs": 13200,
#             "text": "Hi Mary, are you calling because you need health insurance?",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 14080,
#             "endTimeMs": 16400,
#             "text": "Yes, I am calling to sign up for insurance.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 17280,
#             "endTimeMs": 21280,
#             "text": "Great, if you can answer a few questions, we can get you signed up in a jiffy.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 22160,
#             "endTimeMs": 22640,
#             "text": "Okay.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 23520,
#             "endTimeMs": 25040,
#             "text": "So, what is your full name?",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 25920,
#             "endTimeMs": 27040,
#             "text": "Mary Beth Rondo.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 27840,
#             "endTimeMs": 33680,
#             "text": "Last name is R, like Romeo O, like Ocean N, like Nancy D, like dog and O like ocean.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 34480,
#             "endTimeMs": 37120,
#             "text": "Romeo Oscar November Delta Oscar, got it.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 38000,
#             "endTimeMs": 41280,
#             "text": "And what's the best call back number in case we get disconnected?",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 42240,
#             "endTimeMs": 44400,
#             "text": "I only have a cell phone so I can give you that.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 45280,
#             "endTimeMs": 46480,
#             "text": "Yes, that would be fine.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 47360,
#             "endTimeMs": 49360,
#             "text": "Sure, it's two hundred and thirty four.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 50240,
#             "endTimeMs": 51600,
#             "text": "Two hundred and thirty four.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 52560,
#             "endTimeMs": 54080,
#             "text": "Five hundred and fifty four.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 55120,
#             "endTimeMs": 55280,
#             "text": "Mom.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 56240,
#             "endTimeMs": 58400,
#             "text": "And then 9312.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 59280,
#             "endTimeMs": 59760,
#             "text": "Got it.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 59920,
#             "endTimeMs": 63760,
#             "text": "So to confirm it's 2345549312.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 64560,
#             "endTimeMs": 65760,
#             "text": "Yes, that's right.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 66640,
#             "endTimeMs": 67280,
#             "text": "Excellent.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 68160,
#             "endTimeMs": 70960,
#             "text": "Let's get some additional information for your application.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 71840,
#             "endTimeMs": 72720,
#             "text": "Do you have a job?",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 73600,
#             "endTimeMs": 75200,
#             "text": "Yes, I am self-employed.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 76080,
#             "endTimeMs": 78560,
#             "text": "Okay, then do you have a social security number?",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 79440,
#             "endTimeMs": 80240,
#             "text": "Yes, I do.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 81080,
#             "endTimeMs": 82960,
#             "text": "What is your social security number?",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 83840,
#             "endTimeMs": 85360,
#             "text": "It is 412.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 86240,
#             "endTimeMs": 92240,
#             "text": "256789 Sorry, was that a twenty-five or a two hundred and twenty-five?",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 92400,
#             "endTimeMs": 93520,
#             "text": "You cut out for a bit.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 94400,
#             "endTimeMs": 97600,
#             "text": "It's a double two so four one two then another two then five.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 98560,
#             "endTimeMs": 99600,
#             "text": "Thank you so much.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 100400,
#             "endTimeMs": 102240,
#             "text": "Could I please have you e-mail address?",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 103120,
#             "endTimeMs": 103600,
#             "text": "Yeah.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 104400,
#             "endTimeMs": 105040,
#             "text": "It's Mary.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 105840,
#             "endTimeMs": 106480,
#             "text": "Rondo.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 107280,
#             "endTimeMs": 108560,
#             "text": "At gmail.com.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 109440,
#             "endTimeMs": 112080,
#             "text": "So my first and last name at gmail.com.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 112880,
#             "endTimeMs": 113840,
#             "text": "No periods.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 114720,
#             "endTimeMs": 115680,
#             "text": "No dashes.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 116480,
#             "endTimeMs": 122160,
#             "text": "Great, that is the last question, so let me take your information, and I will be able to get you signed up right away.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 123040,
#             "endTimeMs": 127600,
#             "text": "Thank you very much for calling Contoso, and I will be able to get you signed up immediately.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 128480,
#             "endTimeMs": 132880,
#             "text": "One of our agents will call you back within 24 hours to confirm your application.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 133760,
#             "endTimeMs": 134640,
#             "text": "That was quick.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 135440,
#             "endTimeMs": 136080,
#             "text": "Thank you.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 136880,
#             "endTimeMs": 144160,
#             "text": "If you need anything else please give us a call at 1-800-555-555, extension 123.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 144480,
#             "endTimeMs": 146560,
#             "text": "Thank you very much for calling Contoso.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 147440,
#             "endTimeMs": 149200,
#             "text": "Actually I have one more question.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 150000,
#             "endTimeMs": 151040,
#             "text": "Yes of course.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 151920,
#             "endTimeMs": 154560,
#             "text": "Will I be getting a physical card as proof of coverage?",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 155360,
#             "endTimeMs": 160400,
#             "text": "The default is a digital membership card, but we can send you a physical one as well if you prefer.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 161200,
#             "endTimeMs": 163600,
#             "text": "Yes, could you please mail it to me when it's ready?",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 164560,
#             "endTimeMs": 167600,
#             "text": "It'd like it shipped to 2660 Unit A Maple Ave.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 167600,
#             "endTimeMs": 170400,
#             "text": "South, East Lansing for 8823.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 171280,
#             "endTimeMs": 173600,
#             "text": "Absolutely, I've made a note on your file.",
#             "words": []
#           },
#           {
#             "speaker": "2",
#             "startTimeMs": 174480,
#             "endTimeMs": 175840,
#             "text": "Awesome, thanks so much.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 176720,
#             "endTimeMs": 177760,
#             "text": "You're very welcome.",
#             "words": []
#           },
#           {
#             "speaker": "1",
#             "startTimeMs": 178640,
#             "endTimeMs": 181360,
#             "text": "Thank you for calling Contoso and have a great day.",
#             "words": []
#           }
#         ]
#       }
#     ]
#   }
# }

# %% [markdown]
# ## Clean Up
# Optionally, delete the sample analyzer from your resource. In typical usage scenarios, you would analyze multiple files using the same analyzer.

# %%
client.delete_analyzer(ANALYZER_ID)
# Out:
# INFO:python.content_understanding_client_dev_preview2:Analyzer cu-demo-13b055c7-d293-4bb3-911e-3ea3d8bb38e6 deleted.
# <Response [204]>
